# %%
import numpy as np

learning_hours = [1, 2, 6, 4, 10]
grades = [3, 4, 6, 5, 6]

# %%
np.mean(learning_hours)
# Out:
# 4.6

# %%
np.median(learning_hours)
# Out:
# 4.0

# %%
np.std(learning_hours)
# Out:
# 3.2

# %%
np.corrcoef(learning_hours,grades)
# Out:
# array([[1.        , 0.88964891],
#        [0.88964891, 1.        ]])
